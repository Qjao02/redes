# %%
file = open('servConfig/extension.txt','r')
dict = {}
for line in file:
    keyValue = line.split('\t')
    dict[keyValue[0]] = keyValue[1]

# %%
dict
# Out:
# {'.3dm': 'x-world/x-3dmf\n',
#  '.3dmf': 'x-world/x-3dmf\n',
#  '.a': 'application/octet-stream\n',
#  '.aab': 'application/x-authorware-bin\n',
#  '.aam': 'application/x-authorware-map\n',
#  '.aas': 'application/x-authorware-seg\n',
#  '.abc': 'text/vnd.abc\n',
#  '.acgi': 'text/html\n',
#  '.afl': 'video/animaflex\n',
#  '.ai': 'application/postscript\n',
#  '.aif': 'audio/x-aiff\n',
#  '.aifc': 'audio/x-aiff\n',
#  '.aiff': 'audio/x-aiff\n',
#  '.aim': 'application/x-aim\n',
#  '.aip': 'text/x-audiosoft-intra\n',
#  '.ani': 'application/x-navi-animation\n',
#  '.aos': 'application/x-nokia-9000-communicator-add-on-software\n',
#  '.aps': 'application/mime\n',
#  '.arc': 'application/octet-stream\n',
#  '.arj': 'application/octet-stream\n',
#  '.art': 'image/x-jg\n',
#  '.asf': 'video/x-ms-asf\n',
#  '.asm': 'text/x-asm\n',
#  '.asp': 'text/asp\n',
#  '.asx': 'video/x-ms-asf-plugin\n',
#  '.au': 'audio/x-au\n',
#  '.avi': 'video/x-msvideo\n',
#  '.avs': 'video/avs-video\n',
#  '.bcpio': 'application/x-bcpio\n',
#  '.bin': 'application/x-macbinary\n',
#  '.bm': 'image/bmp\n',
#  '.bmp': 'image/x-windows-bmp\n',
#  '.boo': 'application/book\n',
#  '.book': 'application/book\n',
#  '.boz': 'application/x-bzip2\n',
#  '.bsh': 'application/x-bsh\n',
#  '.bz': 'application/x-bzip\n',
#  '.bz2': 'application/x-bzip2\n',
#  '.c': 'text/x-c\n',
#  '.c++': 'text/plain\n',
#  '.cat': 'application/vnd.ms-pki.seccat\n',
#  '.cc': 'text/x-c\n',
#  '.ccad': 'application/clariscad\n',
#  '.cco': 'application/x-cocoa\n',
#  '.cdf': 'application/x-netcdf\n',
#  '.cer': 'application/x-x509-ca-cert\n',
#  '.cha': 'application/x-chat\n',
#  '.chat': 'application/x-chat\n',
#  '.class': 'application/x-java-class\n',
#  '.com': 'text/plain\n',
#  '.conf': 'text/plain\n',
#  '.cpio': 'application/x-cpio\n',
#  '.cpp': 'text/x-c\n',
#  '.cpt': 'application/x-cpt\n',
#  '.crl': 'application/pkix-crl\n',
#  '.crt': 'application/x-x509-user-cert\n',
#  '.csh': 'text/x-script.csh\n',
#  '.css': 'text/css\n',
#  '.cxx': 'text/plain\n',
#  '.dcr': 'application/x-director\n',
#  '.deepv': 'application/x-deepv\n',
#  '.def': 'text/plain\n',
#  '.der': 'application/x-x509-ca-cert\n',
#  '.dif': 'video/x-dv\n',
#  '.dir': 'application/x-director\n',
#  '.dl': 'video/x-dl\n',
#  '.doc': 'application/msword\n',
#  '.dot': 'application/msword\n',
#  '.dp': 'application/commonground\n',
#  '.drw': 'application/drafting\n',
#  '.dump': 'application/octet-stream\n',
#  '.dv': 'video/x-dv\n',
#  '.dvi': 'application/x-dvi\n',
#  '.dwf': 'model/vnd.dwf\n',
#  '.dwg': 'image/x-dwg\n',
#  '.dxf': 'image/x-dwg\n',
#  '.dxr': 'application/x-director\n',
#  '.el': 'text/x-script.elisp\n',
#  '.elc': 'application/x-elc\n',
#  '.env': 'application/x-envoy\n',
#  '.eps': 'application/postscript\n',
#  '.es': 'application/x-esrehber\n',
#  '.etx': 'text/x-setext\n',
#  '.evy': 'application/x-envoy\n',
#  '.exe': 'application/octet-stream\n',
#  '.f': 'text/x-fortran\n',
#  '.f77': 'text/x-fortran\n',
#  '.f90': 'text/x-fortran\n',
#  '.fdf': 'application/vnd.fdf\n',
#  '.fif': 'image/fif\n',
#  '.fli': 'video/x-fli\n',
#  '.flo': 'image/florian\n',
#  '.flx': 'text/vnd.fmi.flexstor\n',
#  '.fmf': 'video/x-atomic3d-feature\n',
#  '.for': 'text/x-fortran\n',
#  '.fpx': 'image/vnd.net-fpx\n',
#  '.frl': 'application/freeloader\n',
#  '.funk': 'audio/make\n',
#  '.g': 'text/plain\n',
#  '.g3': 'image/g3fax\n',
#  '.gif': 'image/gif\n',
#  '.gl': 'video/x-gl\n',
#  '.gsd': 'audio/x-gsm\n',
#  '.gsm': 'audio/x-gsm\n',
#  '.gsp': 'application/x-gsp\n',
#  '.gss': 'application/x-gss\n',
#  '.gtar': 'application/x-gtar\n',
#  '.gz': 'application/x-gzip\n',
#  '.gzip': 'multipart/x-gzip\n',
#  '.h': 'text/x-h\n',
#  '.hdf': 'application/x-hdf\n',
#  '.help': 'application/x-helpfile\n',
#  '.hgl': 'application/vnd.hp-hpgl\n',
#  '.hh': 'text/x-h\n',
#  '.hlb': 'text/x-script\n',
#  '.hlp': 'application/x-winhelp\n',
#  '.hpg': 'application/vnd.hp-hpgl\n',
#  '.hpgl': 'application/vnd.hp-hpgl\n',
#  '.hqx': 'application/x-mac-binhex40\n',
#  '.hta': 'application/hta\n',
#  '.htc': 'text/x-component\n',
#  '.html': 'text/html\n',
#  '.htt': 'text/webviewhtml\n',
#  '.htx': 'text/html\n',
#  '.ice': 'x-conference/x-cooltalk\n',
#  '.ico': 'image/x-icon\n',
#  '.idc': 'text/plain\n',
#  '.ief': 'image/ief\n',
#  '.iefs': 'image/ief\n',
#  '.iges': 'model/iges\n',
#  '.igs': 'model/iges\n',
#  '.ima': 'application/x-ima\n',
#  '.imap': 'application/x-httpd-imap\n',
#  '.inf': 'application/inf\n',
#  '.ins': 'application/x-internett-signup\n',
#  '.ip': 'application/x-ip2\n',
#  '.isdir': 'text/html\n',
#  '.isu': 'video/x-isvideo\n',
#  '.it': 'audio/it\n',
#  '.iv': 'application/x-inventor\n',
#  '.ivr': 'i-world/i-vrml\n',
#  '.ivy': 'application/x-livescreen\n',
#  '.jam': 'audio/x-jam\n',
#  '.jav': 'text/x-java-source\n',
#  '.java': 'text/x-java-source\n',
#  '.jcm': 'application/x-java-commerce\n',
#  '.jfif': 'image/pjpeg\n',
#  '.jfif-tbnl': 'image/jpeg\n',
#  '.jpe': 'image/pjpeg\n',
#  '.jpeg': 'image/pjpeg\n',
#  '.jpg': 'image/jpeg\n',
#  '.jps': 'image/x-jps\n',
#  '.js': 'text/ecmascript\n',
#  '.jut': 'image/jutvision\n',
#  '.kar': 'music/x-karaoke\n',
#  '.ksh': 'text/x-script.ksh\n',
#  '.la': 'audio/x-nspaudio\n',
#  '.lam': 'audio/x-liveaudio\n',
#  '.latex': 'application/x-latex\n',
#  '.lha': 'application/x-lha\n',
#  '.lhx': 'application/octet-stream\n',
#  '.list': 'text/plain\n',
#  '.lma': 'audio/x-nspaudio\n',
#  '.log': 'text/plain\n',
#  '.lsp': 'text/x-script.lisp\n',
#  '.lst': 'text/plain\n',
#  '.lsx': 'text/x-la-asf\n',
#  '.ltx': 'application/x-latex\n',
#  '.lzh': 'application/x-lzh\n',
#  '.lzx': 'application/x-lzx\n',
#  '.m': 'text/x-m\n',
#  '.m1v': 'video/mpeg\n',
#  '.m2a': 'audio/mpeg\n',
#  '.m2v': 'video/mpeg\n',
#  '.m3u': 'audio/x-mpequrl\n',
#  '.man': 'application/x-troff-man\n',
#  '.map': 'application/x-navimap\n',
#  '.mar': 'text/plain\n',
#  '.mbd': 'application/mbedlet\n',
#  '.mc$': 'application/x-magic-cap-package-1.0\n',
#  '.mcd': 'application/x-mathcad\n',
#  '.mcf': 'text/mcf\n',
#  '.mcp': 'application/netmc\n',
#  '.me': 'application/x-troff-me\n',
#  '.mht': 'message/rfc822\n',
#  '.mhtml': 'message/rfc822\n',
#  '.mid': 'x-music/x-midi\n',
#  '.midi': 'x-music/x-midi\n',
#  '.mif': 'application/x-mif\n',
#  '.mime': 'www/mime\n',
#  '.mjf': 'audio/x-vnd.audioexplosion.mjuicemediafile\n',
#  '.mjpg': 'video/x-motion-jpeg\n',
#  '.mm': 'application/x-meme\n',
#  '.mme': 'application/base64\n',
#  '.mod': 'audio/x-mod\n',
#  '.moov': 'video/quicktime\n',
#  '.mov': 'video/quicktime\n',
#  '.movie': 'video/x-sgi-movie\n',
#  '.mp2': 'video/x-mpeq2a\n',
#  '.mp3': 'video/x-mpeg\n',
#  '.mpa': 'video/mpeg\n',
#  '.mpc': 'application/x-project\n',
#  '.mpe': 'video/mpeg\n',
#  '.mpeg': 'video/mpeg\n',
#  '.mpg': 'video/mpeg\n',
#  '.mpga': 'audio/mpeg\n',
#  '.mpp': 'application/vnd.ms-project\n',
#  '.mpt': 'application/x-project\n',
#  '.mpv': 'application/x-project\n',
#  '.mpx': 'application/x-project\n',
#  '.mrc': 'application/marc\n',
#  '.ms': 'application/x-troff-ms\n',
#  '.mv': 'video/x-sgi-movie\n',
#  '.my': 'audio/make\n',
#  '.mzz': 'application/x-vnd.audioexplosion.mzz\n',
#  '.nap': 'image/naplps\n',
#  '.naplps': 'image/naplps\n',
#  '.nc': 'application/x-netcdf\n',
#  '.ncm': 'application/vnd.nokia.configuration-message\n',
#  '.nif': 'image/x-niff\n',
#  '.niff': 'image/x-niff\n',
#  '.nix': 'application/x-mix-transfer\n',
#  '.nsc': 'application/x-conference\n',
#  '.nvd': 'application/x-navidoc\n',
#  '.o': 'application/octet-stream\n',
#  '.oda': 'application/oda\n',
#  '.omc': 'application/x-omc\n',
#  '.omcd': 'application/x-omcdatamaker\n',
#  '.omcr': 'application/x-omcregerator\n',
#  '.p': 'text/x-pascal\n',
#  '.p10': 'application/x-pkcs10\n',
#  '.p12': 'application/x-pkcs12\n',
#  '.p7a': 'application/x-pkcs7-signature\n',
#  '.p7c': 'application/x-pkcs7-mime\n',
#  '.p7m': 'application/x-pkcs7-mime\n',
#  '.p7r': 'application/x-pkcs7-certreqresp\n',
#  '.p7s': 'application/pkcs7-signature\n',
#  '.part': 'application/pro_eng\n',
#  '.pas': 'text/pascal\n',
#  '.pbm': 'image/x-portable-bitmap\n',
#  '.pcl': 'application/x-pcl\n',
#  '.pct': 'image/x-pict\n',
#  '.pcx': 'image/x-pcx\n',
#  '.pdb': 'chemical/x-pdb\n',
#  '.pdf': 'application/pdf\n',
#  '.pfunk': 'audio/make.my.funk\n',
#  '.pgm': 'image/x-portable-greymap\n',
#  '.pic': 'image/pict\n',
#  '.pict': 'image/pict\n',
#  '.pkg': 'application/x-newton-compatible-pkg\n',
#  '.pko': 'application/vnd.ms-pki.pko\n',
#  '.pl': 'text/x-script.perl\n',
#  '.plx': 'application/x-pixclscript\n',
#  '.pm': 'text/x-script.perl-module\n',
#  '.pm4': 'application/x-pagemaker\n',
#  '.pm5': 'application/x-pagemaker\n',
#  '.png': 'image/png\n',
#  '.pnm': 'image/x-portable-anymap\n',
#  '.pot': 'application/vnd.ms-powerpoint\n',
#  '.pov': 'model/x-pov\n',
#  '.ppa': 'application/vnd.ms-powerpoint\n',
#  '.ppm': 'image/x-portable-pixmap\n',
#  '.pps': 'application/vnd.ms-powerpoint\n',
#  '.ppt': 'application/x-mspowerpoint\n',
#  '.ppz': 'application/mspowerpoint\n',
#  '.pre': 'application/x-freelance\n',
#  '.prt': 'application/pro_eng\n',
#  '.ps': 'application/postscript\n',
#  '.psd': 'application/octet-stream\n',
#  '.pvu': 'paleovu/x-pv\n',
#  '.pwz': 'application/vnd.ms-powerpoint\n',
#  '.py': 'text/x-script.phyton\n',
#  '.pyc': 'application/x-bytecode.python\n',
#  '.qcp': 'audio/vnd.qcelp\n',
#  '.qd3': 'x-world/x-3dmf\n',
#  '.qd3d': 'x-world/x-3dmf\n',
#  '.qif': 'image/x-quicktime\n',
#  '.qt': 'video/quicktime\n',
#  '.qtc': 'video/x-qtc\n',
#  '.qti': 'image/x-quicktime\n',
#  '.qtif': 'image/x-quicktime\n',
#  '.ra': 'audio/x-realaudio\n',
#  '.ram': 'audio/x-pn-realaudio\n',
#  '.ras': 'image/x-cmu-raster\n',
#  '.rast': 'image/cmu-raster\n',
#  '.rexx': 'text/x-script.rexx\n',
#  '.rf': 'image/vnd.rn-realflash\n',
#  '.rgb': 'image/x-rgb\n',
#  '.rm': 'audio/x-pn-realaudio\n',
#  '.rmi': 'audio/mid\n',
#  '.rmm': 'audio/x-pn-realaudio\n',
#  '.rmp': 'audio/x-pn-realaudio-plugin\n',
#  '.rng': 'application/vnd.nokia.ringing-tone\n',
#  '.rnx': 'application/vnd.rn-realplayer\n',
#  '.roff': 'application/x-troff\n',
#  '.rp': 'image/vnd.rn-realpix\n',
#  '.rpm': 'audio/x-pn-realaudio-plugin\n',
#  '.rt': 'text/vnd.rn-realtext\n',
#  '.rtf': 'text/richtext\n',
#  '.rtx': 'text/richtext\n',
#  '.rv': 'video/vnd.rn-realvideo\n',
#  '.s': 'text/x-asm\n',
#  '.s3m': 'audio/s3m\n',
#  '.saveme': 'application/octet-stream\n',
#  '.sbk': 'application/x-tbook\n',
#  '.scm': 'video/x-scm\n',
#  '.sdml': 'text/plain\n',
#  '.sdp': 'application/x-sdp\n',
#  '.sdr': 'application/sounder\n',
#  '.sea': 'application/x-sea\n',
#  '.set': 'application/set\n',
#  '.sgm': 'text/x-sgml\n',
#  '.sgml': 'text/x-sgml\n',
#  '.sh': 'text/x-script.sh\n',
#  '.shar': 'application/x-shar\n',
#  '.shtml': 'text/x-server-parsed-html\n',
#  '.sid': 'audio/x-psid\n',
#  '.sit': 'application/x-stuffit\n',
#  '.skd': 'application/x-koan\n',
#  '.skm': 'application/x-koan\n',
#  '.skp': 'application/x-koan\n',
#  '.skt': 'application/x-koan\n',
#  '.sl': 'application/x-seelogo\n',
#  '.smi': 'application/smil\n',
#  '.smil': 'application/smil\n',
#  '.snd': 'audio/x-adpcm\n',
#  '.sol': 'application/solids\n',
#  '.spc': 'text/x-speech\n',
#  '.spl': 'application/futuresplash\n',
#  '.spr': 'application/x-sprite\n',
#  '.sprite': 'application/x-sprite\n',
#  '.src': 'application/x-wais-source\n',
#  '.ssi': 'text/x-server-parsed-html\n',
#  '.ssm': 'application/streamingmedia\n',
#  '.sst': 'application/vnd.ms-pki.certstore\n',
#  '.step': 'application/step\n',
#  '.stl': 'application/x-navistyle\n',
#  '.stp': 'application/step\n',
#  '.sv4cpio': 'application/x-sv4cpio\n',
#  '.sv4crc': 'application/x-sv4crc\n',
#  '.svf': 'image/x-dwg\n',
#  '.svr': 'x-world/x-svr\n',
#  '.swf': 'application/x-shockwave-flash\n',
#  '.t': 'application/x-troff\n',
#  '.talk': 'text/x-speech\n',
#  '.tar': 'application/x-tar\n',
#  '.tbk': 'application/x-tbook\n',
#  '.tcl': 'text/x-script.tcl\n',
#  '.tcsh': 'text/x-script.tcsh\n',
#  '.tex': 'application/x-tex\n',
#  '.texi': 'application/x-texinfo\n',
#  '.texinfo': 'application/x-texinfo\n',
#  '.text': 'text/plain\n',
#  '.tgz': 'application/x-compressed\n',
#  '.tif': 'image/x-tiff\n',
#  '.tiff': 'image/x-tiff\n',
#  '.tr': 'application/x-troff\n',
#  '.tsi': 'audio/tsp-audio\n',
#  '.tsp': 'audio/tsplayer\n',
#  '.tsv': 'text/tab-separated-values\n',
#  '.turbot': 'image/florian\n',
#  '.txt': 'text/plain\n',
#  '.uil': 'text/x-uil\n',
#  '.uni': 'text/uri-list\n',
#  '.unis': 'text/uri-list\n',
#  '.unv': 'application/i-deas\n',
#  '.uri': 'text/uri-list\n',
#  '.uris': 'text/uri-list\n',
#  '.ustar': 'multipart/x-ustar\n',
#  '.uu': 'text/x-uuencode\n',
#  '.uue': 'text/x-uuencode\n',
#  '.vcd': 'application/x-cdlink\n',
#  '.vcs': 'text/x-vcalendar\n',
#  '.vda': 'application/vda\n',
#  '.vdo': 'video/vdo\n',
#  '.vew': 'application/groupwise\n',
#  '.viv': 'video/vnd.vivo\n',
#  '.vivo': 'video/vnd.vivo\n',
#  '.vmd': 'application/vocaltec-media-desc\n',
#  '.vmf': 'application/vocaltec-media-file\n',
#  '.voc': 'audio/x-voc\n',
#  '.vos': 'video/vosaic\n',
#  '.vox': 'audio/voxware\n',
#  '.vqe': 'audio/x-twinvq-plugin\n',
#  '.vqf': 'audio/x-twinvq\n',
#  '.vql': 'audio/x-twinvq-plugin\n',
#  '.vrml': 'x-world/x-vrml\n',
#  '.vrt': 'x-world/x-vrt\n',
#  '.vsd': 'application/x-visio\n',
#  '.vst': 'application/x-visio\n',
#  '.vsw': 'application/x-visio\n',
#  '.w60': 'application/wordperfect6.0\n',
#  '.w61': 'application/wordperfect6.1\n',
#  '.w6w': 'application/msword\n',
#  '.wav': 'audio/x-wav\n',
#  '.wb1': 'application/x-qpro\n',
#  '.wbmp': 'image/vnd.wap.wbmp\n',
#  '.web': 'application/vnd.xara\n',
#  '.wiz': 'application/msword\n',
#  '.wk1': 'application/x-123\n',
#  '.wmf': 'windows/metafile\n',
#  '.wml': 'text/vnd.wap.wml\n',
#  '.wmlc': 'application/vnd.wap.wmlc\n',
#  '.wmls': 'text/vnd.wap.wmlscript\n',
#  '.wmlsc': 'application/vnd.wap.wmlscriptc\n',
#  '.word': 'application/msword\n',
#  '.wp': 'application/wordperfect\n',
#  '.wp5': 'application/wordperfect6.0\n',
#  '.wp6': 'application/wordperfect\n',
#  '.wpd': 'application/x-wpwin\n',
#  '.wq1': 'application/x-lotus\n',
#  '.wri': 'application/x-wri\n',
#  '.wrl': 'x-world/x-vrml\n',
#  '.wrz': 'x-world/x-vrml\n',
#  '.wsc': 'text/scriplet\n',
#  '.wsrc': 'application/x-wais-source\n',
#  '.wtk': 'application/x-wintalk\n',
#  '.x-png': 'image/png\n',
#  '.xbm': 'image/xbm\n',
#  '.xdr': 'video/x-amt-demorun\n',
#  '.xgz': 'xgl/drawing\n',
#  '.xif': 'image/vnd.xiff\n',
#  '.xl': 'application/excel\n',
#  '.xla': 'application/x-msexcel\n',
#  '.xlb': 'application/x-excel\n',
#  '.xlc': 'application/x-excel\n',
#  '.xld': 'application/x-excel\n',
#  '.xlk': 'application/x-excel\n',
#  '.xll': 'application/x-excel\n',
#  '.xlm': 'application/x-excel\n',
#  '.xls': 'application/x-msexcel\n',
#  '.xlt': 'application/x-excel\n',
#  '.xlv': 'application/x-excel\n',
#  '.xlw': 'application/x-msexcel\n',
#  '.xm': 'audio/xm\n',
#  '.xml': 'text/xml\n',
#  '.xmz': 'xgl/movie\n',
#  '.xpix': 'application/x-vnd.ls-xpix\n',
#  '.xpm': 'image/xpm\n',
#  '.xsr': 'video/x-amt-showrun\n',
#  '.xwd': 'image/x-xwindowdump\n',
#  '.xyz': 'chemical/x-pdb\n',
#  '.z': 'application/x-compressed\n',
#  '.zip': 'multipart/x-zip\n',
#  '.zoo': 'application/octet-stream\n',
#  '.zsh': 'text/x-script.zsh\n'}

# %%
listRemove = []
for k,v in dict.items():
    if v == 'text/html':
        listRemove.append(k)

# %%
listRemove
# Out:
# []

# %%
string = '\r\n'
string.encode()
# Out:
# b'\r\n'

# %%
string
# Out:
# '\r\n'

# %%
file = open('content/j.pdf','rb')

# %%
file.read()
# Out:
# b'%PDF-1.5\n%\xbf\xf7\xa2\xfe\n6 0 obj\n<< /Linearized 1 /L 79582 /H [ 848 156 ] /O 10 /E 68672 /N 2 /T 79280 >>\nendobj\n                                                                                                                \n7 0 obj\n<< /Type /XRef /Length 83 /Filter /FlateDecode /DecodeParms << /Columns 5 /Predictor 12 >> /W [ 1 3 1 ] /Index [ 6 38 ] /Info 23 0 R /Root 8 0 R /Size 44 /Prev 79281                 /ID [<eb36c5649fbd6ec2dbafaf56e96d0e10><eb36c5649fbd6ec2dbafaf56e96d0e10>] >>\nstream\nx\x9ccbd`\xe0g`b``8\t"\x99\xdd\xc0l#09\x07D2\xfe\x05\x91\\. RI\x15,\x92\x0f"\xbdo\x83H\xa66\x10\xa9\xc0\x01\x16\xf7\x02\x91zk\xc0lu \xc9h:\x0b\xac\xe68\x03\x13\xe3\xff\xdfy`3\x19\x18\xe9O\x02\x00&\xc1\x0by\nendstream\nendobj\n                                                                                                                                                                                                             \n8 0 obj\n<< /Pages 24 0 R /Type /Catalog >>\nendobj\n9 0 obj\n<< /Filter /FlateDecode /S 49 /Length 79 >>\nstream\nx\x9cc```a``\x0e\x00\x91\x9a\x85\x0c\x02\x0cP\x00f3\x83D\x19X&\xdc{\xcc\xc0 \xd2\xb9\xfa\x00\x88F\x02\xbcP\xcc\xc0\xf0\x97\x81\x9f\x81AQ\x96\xd3\x81]\xd3\xfa\x80\x92\x7fk\x83od\x1c\xc3\xca%/x\x16lN``\x00\x00t\xff\x11\x1b\nendstream\nendobj\n10 0 obj\n<< /Contents 11 0 R /MediaBox [ 0 0 596 843 ] /Parent 24 0 R /Resources << /ExtGState << /G0 25 0 R >> /Font << /F0 26 0 R /F1 29 0 R /F2 32 0 R /F3 35 0 R /F4 38 0 R >> /ProcSets [ /PDF /Text /ImageB /ImageC /ImageI ] >> /Type /Page >>\nendobj\n11 0 obj\n<< /Filter /FlateDecode /Length 2299 >>\nstream\nx\x9c\xe5[[\x8b,\xb9\r~\x9f_\xd1\xcf\x81xm\xf9\x0ea\xa1\xa7{\xce>\'\x0c\xe4\x07$\xd9\x85\xc0.d\xf3\xff!\xb2-\xd9.W_\xec:3\x93\x87=C\x9f\xaa\xae*\xc9\xb2\xac\xdb\'W\xab\x93\xc4\xbf?+\xfc/\x18}\xfa\xc7\xaf/\xffyIWltx\x01D\xb4^\xd9\xd3\xef\xffz\xf9\xfb\x9fN\xbf\xe1=\xe1\xadt\x10=d\xba\xed7$V\xa7\xf4\xf7\xb7\x9fN\xe5\xe4\xf7_^~\xf8I\x9e~\xf9o\xe6\xe9\xa39)\x05:\xb1\xfb\xf9\xc1\x15\x00\xe3\xee?\x83\x82\xe5K\x12|{H\xa61\xcb\t\x8e\xf9\xfa\xfe\xf2\xc37y\x02sz\xff\xf9E\xb5\x19*\x15O\xef\xbf\xbe \x07yz\xff\xe7\xe9/R\xc2\x9b\x94VK\x88\xd7|\x94\xd2\xe05\x8b\xe7\x11O_\xcb\xd1z\xfc\x84v\xdf\xe0\xb9\xb1\xf4l\xba\xe7\xe8\xb9\xb7\x1fO\xef\xff~y{\x7f6\xbe\xd6FX\xe3B`1\xc0\x87\r)\xaa\xce\x8d\xa4F\x0e\xa2K\xbd\xa1\x81\x1b4v7\xdd$&\xd0\x14b\x11\x1d\x8fpVez\xea\xadLK\xe3u\x054\xc5\xb72]V\x81q\xc8\x06U\x83$\xf9~\xe2\xe7\xf1\x8b\xc2g\x14>\xa3^IM\x89\xc6\x14>*\xf13\xe5\x98\xee\xe1G\x05Ec\xa9-\x7f\x9b\xc6\xbb\x92\x9c\x17\xba\xe6\'\xe7j\x8c\x14\xce\xab\xfb\xaa\xbdE\xea\xc3\xa0&\xed\x07\x8b\xb8a%U\x85\xb2\xa9,}O\xa2\xe7)^\xca\xd4 \xa9\xe3\xba\x9dr\xb2\x9a\xb4\x14\xda4\x95+\xbc\xa6\xce\xa4.O\xea\x8a\xf4\xdd\xd0=39\x17\x1d\xac\x90>(\xbd\xa2\x86\xe8G5tS\xccb\xbc\xb5\xa9e\x11]\x9d\x9aTW\xfa\\\xc8\x12\xd25E\xd7\xce\xed\x98\x9f\xd5\x13|\x98\xeeL|,\x9d\xbbbe\xd9\xf2\xd8\xca\\sH\xcb\xcb\xe0\xcb5\x93\xadjr\xee\xc6\x81\xf0\xda\xe8\x15\xeb\x81te\xebd\xa1\x194\x8b\xc5\xd6\xc2\x0e\x93\xef{\x123Y\x95"UCs\x84j\x19\x96\xa6\xadI\xad\x17:\xb7\xbd\xaa&\xe5\xd4\xe0\x05\xa0a\xaeX\x06\x93j%d\xd4\xde\xae\x90j{#\x04\xa5\x05\xb5\xe4\xf6y\xf6\xb2\xcd\xd6\xbcQ\x98\xb1t\xd4EK-\xca\xb6P\x02\xa6\x0b\x11\xe1\x06O \xdat_M\xca\x9a\xa2\xb3y0\xcb\x1b\xc1\x19\xac\xb9\x1b\x9c\x85\xd5\xfa\xd4\xfe\xc345\\\xc1|\x85b\x9f\xc0+L\xba&%\xcd\x07I\xed\xd6\xe0^\xa7\xc1]\x0c7F\xcfD\xfa\x06Q\x84\xd1\xd9\xa1\xe9.;\x8d\'\xddf\xab\x9c\xe4\x87\x8b\xf2@\x08\x0c\xcd6\xe2\xbf0\x10k9\xba\xd0\xf3\xdc\xa6aT9\xb0\xb7s\xfa\xbeR4\xa0c6\xae4\x99\x0bE\x8eX\xef\xc3\x99\xdd\x92\xdc\xb1F\x13h\x01\xbf\xba\xa8\x1b\xa3K\xcb\x85\x9c\xf3\xea\xb8\x94W9B\xb1\x1c\x95\x17\x95\x17\x99\x96\r\x95\xe5\xe09p^\xf4\xdd\x1cTs\x96\xcc\xf7\\\x8e\xda7g\xc9\xb4\xa6\xd03]N>\x97\x12\xd9Sr\xd2\xd9I\x9e\x997\xe9\xday+|\x1f:\x0eX\xb96\x07\xad\x1c\xa3\xf2\xba\x95k7Z9\x17@\xd9H\x92>P!\xee\x1b~\xa8\xe0H\x1a\xc9Q\xc5\x95{I\x99\x1e\xe8\xd9\x0b_\x9f\x1c\x17\x9c\x12\x06\xebc\xbbb\xd7AmE\x9e\x08\xb2(\xe78MO\xb6\xe5\xa8|\xd5\xfb4Tk\xacs\xb3Q\xb4\xab\\\xdb\xe5\xd4umv.M\ ...

# %% [markdown]
# ####'GET / HTTP/1.1\r\nHost: 10.0.0.248:7000\nConnection: keep-alive\nUpgrade-Insecure-Requests: 1\nUser-Agent: jaoClient\nAcept-Encoding: gzir, deflate, br\nAccept-Language: en-US,en;q=0.9,pt-BR;q=0.8,pt;q=0.7\n'
